# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
file = open('calls.csv')
df = pd.read_csv(file)
df
# Out:
#       timestamp  caller  callee  duration
# 0           184     300     301       121
# 1          3920     512     299       670
# 2          5623     301     300       504
# 3          9252     401     457        -1
# 4         15466     512       0         5
# ...         ...     ...     ...       ...
# 3595    2414934     706     401        78
# 3596    2415585     218     382        48
# 3597    2416059     561     631        13
# 3598    2416368     323     392         4
# 3599    2416399     323     392         3
#
# [3600 rows x 4 columns]

# %%
G = nx.from_pandas_edgelist(df, 'caller', 'callee', ['timestamp', 'duration'], create_using=nx.DiGraph())
plt.figure(figsize=(6,6))
nx.draw(G, node_size=16)
